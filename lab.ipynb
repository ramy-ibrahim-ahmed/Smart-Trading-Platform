# %%
data = {
    "users": [
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f49323258b0>",
            "id": 1,
            "hashed_password": "$2b$12$C8xcMn/zjY84MvEPor8Z.OWzyHdZiVcqhZ.3Vdp0V2lqSs2YVMU1C",
            "created_at": "2025-11-08 14:17:01.490831+00:00",
            "username": "string",
            "email": "user@example.com",
            "is_active": True,
            "updated_at": None,
        },
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f4932325910>",
            "id": 2,
            "hashed_password": "$2b$12$Vd4QD7xU25v9uX7FxHzkL.vtYhTwpbeMMeGpeu6Qcg0GCoOwpowGe",
            "created_at": "2025-11-09 21:25:43.617409+00:00",
            "username": "ramy",
            "email": "ramy@gmail.com",
            "is_active": True,
            "updated_at": None,
        },
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f4932325970>",
            "id": 5,
            "hashed_password": "$2b$12$eYDb/ulDXRoN3VLbk.1jzu2MN1o2a7v4Y1frOzgjaAMYFgAIMjYFW",
            "created_at": "2025-11-10 21:57:12.364395+00:00",
            "username": "abc",
            "email": "abc@gmail.com",
            "is_active": True,
            "updated_at": None,
        },
    ],
    "cars": [
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f4932327530>",
            "transmission": "string",
            "num_in_stock": 0,
            "id": 1,
            "fuel_type": "string",
            "description": "string",
            "model": "string",
            "mileage_km": 0,
            "year": 0,
            "top_speed_kmh": 0,
            "body_type": "string",
            "color": "string",
            "engine_type": "string",
            "features": "string",
            "brand": "string",
            "engine_size_liters": 0.0,
            "price_usd": "0.00",
            "horsepower": 0,
            "discount_percent": "0.00",
        },
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f4932327590>",
            "transmission": "string",
            "num_in_stock": 0,
            "id": 2,
            "fuel_type": "string",
            "description": "string",
            "model": "string",
            "mileage_km": 0,
            "year": 0,
            "top_speed_kmh": 0,
            "body_type": "string",
            "color": "string",
            "engine_type": "string",
            "features": "string",
            "brand": "string",
            "engine_size_liters": 0.0,
            "price_usd": "0.00",
            "horsepower": 0,
            "discount_percent": "0.00",
        },
    ],
    "orders": [
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f4932327bf0>",
            "user_id": 5,
            "created_at": "2025-11-10 22:10:42.876358+00:00",
            "id": 3,
        },
        {
            "_sa_instance_state": "<sqlalchemy.orm.state.InstanceState object at 0x7f4932327c50>",
            "user_id": 5,
            "created_at": "2025-11-10 22:11:20.463643+00:00",
            "id": 4,
        },
    ],
    "order_items": [{"order_id": 4, "car_id": 2}, {"order_id": 4, "car_id": 1}],
}

# %%
for d in data["cars"]:
    d.pop("_sa_instance_state", None)

# %%
data["cars"]
# Out:
# [{'transmission': 'string',
#   'num_in_stock': 0,
#   'id': 1,
#   'fuel_type': 'string',
#   'description': 'string',
#   'model': 'string',
#   'mileage_km': 0,
#   'year': 0,
#   'top_speed_kmh': 0,
#   'body_type': 'string',
#   'color': 'string',
#   'engine_type': 'string',
#   'features': 'string',
#   'brand': 'string',
#   'engine_size_liters': 0.0,
#   'price_usd': '0.00',
#   'horsepower': 0,
#   'discount_percent': '0.00'},
#  {'transmission': 'string',
#   'num_in_stock': 0,
#   'id': 2,
#   'fuel_type': 'string',
#   'description': 'string',
#   'model': 'string',
#   'mileage_km': 0,
#   'year': 0,
#   'top_speed_kmh': 0,
#   'body_type': 'string',
#   'color': 'string',
#   'engine_type': 'string',
#   'features': 'string',
#   'brand': 'string',
#   'engine_size_liters': 0.0,
#   'price_usd': '0.00',
#   'horsepower': 0,
#   'discount_percent': '0.00'}]

# %%
import json

cars_str = "\n\n---\n\n".join(
    [json.dumps(d, indent=4, sort_keys=True) for d in data["cars"]]
)

# %%
print(cars_str)
# Out:
# {
#     "body_type": "string",
#     "brand": "string",
#     "color": "string",
#     "description": "string",
#     "discount_percent": "0.00",
#     "engine_size_liters": 0.0,
#     "engine_type": "string",
#     "features": "string",
#     "fuel_type": "string",
#     "horsepower": 0,
#     "id": 1,
#     "mileage_km": 0,
#     "model": "string",
#     "num_in_stock": 0,
#     "price_usd": "0.00",
#     "top_speed_kmh": 0,
#     "transmission": "string",
#     "year": 0
# }
#
# ---
#
# {
#     "body_type": "string",
#     "brand": "string",
#     "color": "string",
#     "description": "string",
#     "discount_percent": "0.00",
#     "engine_size_liters": 0.0,
#     "engine_type": "string",
#     "features": "string",
#     "fuel_type": "string",
#     "horsepower": 0,
#     "id": 2,
#     "mileage_km": 0,
#     "model": "string",
#     "num_in_stock": 0,
#     "price_usd": "0.00",
#     "top_speed_kmh": 0,
#     "transmission": "string",
#     "year": 0
# }
